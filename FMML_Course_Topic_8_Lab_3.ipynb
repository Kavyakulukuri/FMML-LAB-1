# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavyakulukuri/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 16:13:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   209MB/s    in 0.3s
#
# 2024-04-05 16:13:58 (209 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 557    1604.06529v2  We propose a transition-based dependency parse...    cs
# 40594   0910.2034v2  In this paper we adapt online estimation strat...  stat
# 19735   1205.2637v1  A major benefit of graphical models is that mo...    cs
# 15184  1612.00567v1  Transition-based models can be fast and accura...    cs
# 37161  1609.02531v1  This paper reports the activities and outcomes...    cs
# ...             ...                                                ...   ...
# 34466  1609.07680v1  The power law is ubiquitous in natural and soc...    cs
# 12567  1803.00276v2  The problem of complex data analysis is a cent...  stat
# 36720   1404.0540v1  Efficient modeling on uncertain information pl...    cs
# 19956   1303.5709v1  Theory refinement is the task of updating a do...    cs
# 24804   1412.0065v1  We focus on the task of everyday hand pose est...    cs
#
#                                                    title  year  \
# 557    Dependency Parsing with LSTMs: An Empirical Ev...  2016
# 40594  Strategies for online inference of model-based...  2009
# 19735                        Counting Belief Propagation  2012
# 15184  Shift-Reduce Constituent Parsing with Neural L...  2016
# 37161  Latest Datasets and Technologies Presented in ...  2016
# ...                                                  ...   ...
# 34466  Existence of Hierarchies and Human's Pursuit o...  2016
# 12567  Model-Based Clustering and Classification of F...  2018
# 36720  Modeling contaminant intrusion in water distri...  2014
# 19956             Theory Refinement on Bayesian Networks  2013
# 24804  3D Hand Pose Detection in Egocentric RGB-D Images  2014
#
#                                                 keywords
# 557    [transition, dependency, recurrent, feedforwar...
# 40594  [estimation, strategies, clustering, algorithm...
# 19735  [graphical, knowledge, structure, inference, s...
# 15184  [transition, constituent, extracting, informat...
# 37161  [activities, manipulation, organized, internat...
# ...                                                  ...
# 34466  [ubiquitous, phenomena, considered, universal,...
# 12567  [statistical, increasing, prevalence, dimensio...
# 36720  [efficient, uncertain, information, important,...
# 19956  [refinement, automatically, assistance, refine...
# 24804  [estimation, egocentric, viewpoints, particula...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 557      [transition, dependency, recurrent, feedforwar...
# 40594    [estimation, strategies, clustering, algorithm...
# 19735    [graphical, knowledge, structure, inference, s...
# 15184    [transition, constituent, extracting, informat...
# 37161    [activities, manipulation, organized, internat...
#                                ...
# 11593    [techniques, achieving, remarkable, representa...
# 37981    [inference, unsynchronized, primarily, variati...
# 6028     [parameters, voluminous, prohibitive, computat...
# 29687    [generation, applications, entertainment, enfo...
# 21661    [transportation, distances, fundamental, param...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8812 words.
# Out of those 4544 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="72995d9e-0777-49c6-90f7-5f9f43c75e94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72995d9e-0777-49c6-90f7-5f9f43c75e94")) {                    Plotly.newPlot(                        "72995d9e-0777-49c6-90f7-5f9f43c75e94",                        [{"x":["additionally","generalisation","propagation","transition","decisions","competitive","empirical","embedding","difficult","sequences","dependencies","improvement","regularisation","dependency","feedforward","modelling","evaluation","recurrent","information","strategies","simulated","algorithm","parameters","structure","political","algorithms","estimating","distributions","clustering","estimation","precision","variational","approaches","inference","important","obtainable","magnitude","graphical","constructs","corresponding","reflected","additional","exploitable","indistinguishable","experiments","efficiency","symmetries","compressed","applicable","significant","knowledge","relational","equivalent","efficient","techniques","lookahead","resulting","limitation","hierarchy","particular","constituents","supervised","extracting","accuracies","incremental","bidirectional","leverages","constituent","collection","international","activities","discussed","comparable","summarizes","hopefully","conference","directions","organized","available","communities","automation","indicates","presented","commented","explorations","displayed","interactive","importance","developments","manipulation","presentations","technologies","discussion","partially","statistical","diagnosis","framework","traditionally","experiment","utilities","components","estimates","questions","generalization","variables","technique","statistically","factorization","functions","generalized","gaussians","structures","selection","criterion","significantly","uncertainty","procedure","synthetic","elicitation","subpopulations","represent","discovering","attributes","population","discovery","additivity","distribution","programming","evolution","continuous","dynamical","investigation","traditional","condition","representations","representation","classifier","encodings","asynchronous","production","explosion","supernova","combinations","conventional","effectively","explanatory","regression","confirmed","determine","astronomy","beforehand","measurement","collecting","relaxation","difficulty","summarized","approximate","exhaustively","reconstructed","histogram","exhaustive","understanding","appropriate","selecting","combinatorial","different","combination","computing","literature","numerical","rectangular","nonnegative","predicting","databases","observations","performed","movielens","recommendations","containing","personalized","recommender","represented","evaluations","promising","tractably","generated","theoretical","mechanism","improving","restriction","statistics","proposals","calculate","calculated","confident","thresholding","processing","efficiently","incorrect","correctly"],"y":[71,9,70,36,53,111,163,88,115,111,47,113,5,54,26,52,232,148,680,92,60,856,233,336,13,581,61,125,168,191,83,44,427,185,361,1,58,57,31,125,7,114,2,5,616,170,5,23,52,233,316,37,47,432,371,4,153,23,42,253,9,204,55,31,35,22,27,12,69,26,35,57,84,1,6,9,40,8,299,20,6,24,201,2,2,8,48,85,26,21,5,46,21,45,176,57,559,28,103,5,98,84,61,111,143,241,26,25,216,74,8,132,166,46,235,89,120,138,8,2,140,36,64,37,64,2,200,119,46,103,19,34,192,59,223,396,156,7,17,23,9,0,48,110,114,6,129,12,80,3,2,38,14,23,39,2,99,9,19,26,21,167,88,45,45,774,152,125,149,92,4,7,90,64,74,147,2,12,69,14,14,77,56,127,0,172,155,116,108,9,69,27,24,22,3,21,253,166,8,33],"type":"bar"},{"x":["additionally","generalisation","propagation","transition","decisions","competitive","empirical","embedding" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4544,), (4544, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.38624338624338633);'>Assumptions</span> <span style=''>Behind</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Dempsters</span> <span style=''>Rule</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>examines</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3392070484581498);'>combination</span> <span style=''>rule</span> <span style=''>for</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>It</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>two</span> <span style=''>fairly</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>apparently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reasonable</span> <span style='background-color:rgba(255, 0, 0, 0.38624338624338633);'>assumptions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Dempsters</span> <span style=''>rule</span> <span style=''>giving</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.4615384615384615);'>justification</span> <span style=''>for</span> <span style=''>it</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimality</span> <span style=''>of</span> <span style=''>Local</span> <span style=''>Search</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style=''>Recovery</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>there</span> <span style=''>are</span> <span style=''>no</span> <span style=''>spurious</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>in</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>recovery</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incoherent</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>With</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>we</span> <span style=''>show</span> <span style=''>all</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>are</span> <span style=''>very</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>Together</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>bound</span> <span style=''>at</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>this</span> <span style=''>yields</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>em</span> <span style=''>from</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bolasso</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>Lasso</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>bootstrap</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>least</span> <span style=''>square</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.47022587268993843);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.36800000000000005);'>regularization</span> <span style=''>by</span> <span style=''>the</span> <span style=''>l1</span> <span style=''>norm</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>usually</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>detailed</span> <span style='background-color:rgba(255, 0, 0, 0.7227722772277227);'>asymptotic</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>For</span> <span style=''>various</span> <span style=''>decays</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.36800000000000005);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.35625000000000007);'>parameter</span> <span style=''>we</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.7227722772277227);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>equivalents</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>correct</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>(ie</span> <span style=''>variable</span> <span style=''>selection)</span> <span style=''>For</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>rate</span> <span style=''>decay</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30917874396135253);'>variables</span> <span style=''>that</span> <span style=''>should</span> <span style=''>enter</span> <span style=''>the</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>tending</span> <span style=''>to</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>fast</span> <span style=''>while</span> <span style=''>it</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.30917874396135253);'>variables</span> <span style=''>with</span> <span style=''>strictly</span> <span style=''>positive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>property</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>if</span> <span style=''>we</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Angle</span> <span style=''>Based</span> <span style=''>Joint</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explained</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Integrative</span> <span style=''>analysis</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disparate</span> <span style=''>data</span> <span style=''>blocks</span> <span style=''>measured</span> <span style=''>on</span> <span style=''>a</span> <span style=''>common</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>subjects</span> <span style=''>is</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>This</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>of</span> <span style=''>the</span> <span style=''>joint</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>within</span> <span style=''>each</span> <span style=''>data</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>new</span> <span style=''>insights</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>strong</span> <span style=''>desire</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style=''>the</span> <span style=''>multiple</span> <span style=''>genomic</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>in</span> <span style=''>The</span> <span style=''>Cancer</span> <span style=''>Genome</span> <span style=''>Atlas</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>common</span> <span style=''>and</span> <span style=''>also</span> <span style=''>the</span> <span style=''>unique</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>cancer</span> <span style=''>genetics</span> <span style=''>and</span> <span style=''>cell</span> <span style=''>biology</span> <span style=''>for</span> <span style=''>each</span> <span style=''>source</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Angle</span> <span style=''>Based</span> <span style=''>Joint</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capturing</span> <span style=''>both</span> <span style=''>joint</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>within</span> <span style=''>each</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.04885057471264368)
# 	challenging (0.09375)
# 	architecture (0.08656609195402298)
# 	segmentation (0.07040229885057471)
# 	information (0.2442528735632184)
# 	detection (0.11530172413793104)
# 	representation (0.14224137931034483)
# 	convolutional (0.13038793103448276)
# 	recognition (0.1307471264367816)
# 	different (0.27801724137931033)
#
# Some Statistics words are:
# 	optimization (0.19196428571428573)
# 	variables (0.13442460317460317)
# 	stochastic (0.13343253968253968)
# 	estimation (0.16567460317460317)
# 	statistical (0.16170634920634921)
# 	theoretical (0.15674603174603174)
# 	distribution (0.18353174603174602)
# 	dimensional (0.18353174603174602)
# 	inference (0.1909722222222222)
# 	regression (0.1775793650793651)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="14f75f98-c85c-4a0c-a494-29b104feb302" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14f75f98-c85c-4a0c-a494-29b104feb302")) {                    Plotly.newPlot(                        "14f75f98-c85c-4a0c-a494-29b104feb302",                        [{"x":["additionally","generalisation","propagation","transition","decisions","competitive","empirical","embedding","difficult","sequences","dependencies","improvement","regularisation","dependency","feedforward","modelling","evaluation","recurrent","information","strategies","simulated","algorithm","parameters","structure","political","algorithms","estimating","distributions","clustering","estimation","precision","variational","approaches","inference","important","obtainable","magnitude","graphical","constructs","corresponding","reflected","additional","exploitable","indistinguishable","experiments","efficiency","symmetries","compressed","applicable","significant","knowledge","relational","equivalent","efficient","techniques","lookahead","resulting","limitation","hierarchy","particular","constituents","supervised","extracting","accuracies","incremental","bidirectional","leverages","constituent","collection","international","activities","discussed","comparable","summarizes","hopefully","conference","directions","organized","available","communities","automation","indicates","presented","commented","explorations","displayed","interactive","importance","developments","manipulation","presentations","technologies","discussion","partially","statistical","diagnosis","framework","traditionally","experiment","utilities","components","estimates","questions","generalization","variables","technique","statistically","factorization","functions","generalized","gaussians","structures","selection","criterion","significantly","uncertainty","procedure","synthetic","elicitation","subpopulations","represent","discovering","attributes","population","discovery","additivity","distribution","programming","evolution","continuous","dynamical","investigation","traditional","condition","representations","representation","classifier","encodings","asynchronous","production","explosion","supernova","combinations","conventional","effectively","explanatory","regression","confirmed","determine","astronomy","beforehand","measurement","collecting","relaxation","difficulty","summarized","approximate","exhaustively","reconstructed","histogram","exhaustive","understanding","appropriate","selecting","combinatorial","different","combination","computing","literature","numerical","rectangular","nonnegative","predicting","databases","observations","performed","movielens","recommendations","containing","personalized","recommender","represented","evaluations","promising","tractably","generated","theoretical","mechanism","improving","restriction","statistics","proposals","calculate","calculated","confident","thresholding","processing","efficiently","incorrect","correctly","bootstrapped","irrelevant","specifically","subsequently","identifying","character","conditioned","certainty","assumptions","identified","probability","translated","recognition","documents","posterior","relatively","introduce","probabilities","confidence","continuation","investigated","applications","composition","regarding","conditions","controllability","fundamental","particularly","complexity","properties","presenting","practical","demonstrate","supervisory","existence","subjectivity","consideration","reachable","reformulate","described","illustrate","fuzziness","considered","developed","restoration","deblurring","convergence","investigate","biomedical","outperform","application","preserving","utilizing","motivated","convergent","corrupted","alternati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	supernova
# 	tractably
# 	accompanies
# 	deterioration
# 	hemoglobin
# 	chemicals
# 	subgaussian
# 	retrospective
# 	submodularity
# 	plentiful
# 	regressions
# 	curvatures
# 	emphdirectly
# 	representer
# 	rightarrow
# 	directionally
# 	concordance
# 	strikingly
# 	integrable
# 	embarrassingly
# Some words which never appear in Statistics papers:
# 	lookahead
# 	commented
# 	certainty
# 	continuation
# 	controllability
# 	subjectivity
# 	fuzziness
# 	deblurring
# 	avoidance
# 	backwards
# 	localizing
# 	localizes
# 	exposures
# 	luminance
# 	afterwards
# 	superfluous
# 	accordance
# 	propositional
# 	encapsulation
# 	designers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0879446640316203e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658333333333334
